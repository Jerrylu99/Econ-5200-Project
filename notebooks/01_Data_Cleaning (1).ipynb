# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-42461925-9bf9-49a0-a915-c92a4d208134" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42461925-9bf9-49a0-a915-c92a4d208134">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import shutil

# create raw folder
os.makedirs("/content/5200-Project/data/raw", exist_ok=True)

# move dataset
shutil.move("/content/public.dat",
            "/content/5200-Project/data/raw/public.dat")

print("Dataset moved to data/raw/")
# Out:
# Dataset moved to data/raw/

# %%
import pandas as pd

data_path = "/content/5200-Project/data/raw/public.dat"

df = pd.read_fwf(data_path)

df.head()
# Out:
#     46  1  0  0.1  0.2  0.3  0.4  1.1  0.5  0.6  ...  0.08 1.6 2.1 6.50.1  \
# 0   49  2  0    0    0    0    0    1    0    0  ...  0.05   0   2  10.00
# 1  506  2  1    0    0    0    0    1    0    0  ...  0.25   .   1  11.00
# 2   56  4  1    0    0    0    0    1    0    0  ...  0.15   0   2  10.00
# 3   61  4  1    0    0    0    0    1    0    0  ...  0.15   0   2  10.00
# 4   62  4  1    0    0    0    0    1    0    0  ...     .   0   2  10.00
#
#   16.50.1 1.03.2   ..3  0.94  4  4.1
# 0   13.00   1.01  0.89  2.35  4    4
# 1   11.00   0.95  0.74  2.33  4    3
# 2   12.00   0.92  0.79  0.87  2    2
# 3   12.00   1.01  0.84  0.95  2    2
# 4   12.00      .  0.84  1.79  3    3
#
# [5 rows x 46 columns]

# %%
print("Dataset shape:", df.shape)
df.info()
# Out:
# Dataset shape: (409, 46)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 46 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   46       409 non-null    int64
#  1   1        409 non-null    int64
#  2   0        409 non-null    int64
#  3   0.1      409 non-null    int64
#  4   0.2      409 non-null    int64
#  5   0.3      409 non-null    int64
#  6   0.4      409 non-null    int64
#  7   1.1      409 non-null    int64
#  8   0.5      409 non-null    int64
#  9   0.6      409 non-null    int64
#  10  0.7      409 non-null    int64
#  11  30.00    409 non-null    object
#  12  15.00    409 non-null    object
#  13  3.00     409 non-null    object
#  14  .        409 non-null    object
#  15  19.0     409 non-null    object
#  16  ..1      409 non-null    object
#  17  1.2      409 non-null    int64
#  18  ..2      409 non-null    object
#  19  2        409 non-null    int64
# ...
